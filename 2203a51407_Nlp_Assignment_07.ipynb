# %% [markdown]
# (a) Data Preprocessing

# %%
# Step 1: Install TensorFlow and necessary libraries
# !pip install tensorflow numpy

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Example data (small English to French pairs)
data = [("hello", "bonjour"),
        ("how are you", "comment ça va"),
        ("I am fine", "je vais bien"),
        ("what is your name", "comment tu t'appelles"),
        ("my name is", "je m'appelle"),
        ("thank you", "merci"),
        ("goodbye", "au revoir")]

# Splitting the data into input (English) and output (French) pairs
english_sentences, french_sentences = zip(*data)

# Tokenize English sentences
eng_tokenizer = Tokenizer()
eng_tokenizer.fit_on_texts(english_sentences)
eng_sequences = eng_tokenizer.texts_to_sequences(english_sentences)
eng_word_index = eng_tokenizer.word_index
max_eng_len = max(len(seq) for seq in eng_sequences)

# Tokenize French sentences
fr_tokenizer = Tokenizer()
fr_tokenizer.fit_on_texts(french_sentences)
fr_sequences = fr_tokenizer.texts_to_sequences(french_sentences)
fr_word_index = fr_tokenizer.word_index
max_fr_len = max(len(seq) for seq in fr_sequences)

# Padding sequences
eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
fr_padded = pad_sequences(fr_sequences, maxlen=max_fr_len, padding='post')

# Vocabulary sizes
eng_vocab_size = len(eng_word_index) + 1
fr_vocab_size = len(fr_word_index) + 1
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %% [markdown]
# (b) Build Seq2Seq Model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding

# Encoder
latent_dim = 256

encoder_inputs = Input(shape=(max_eng_len,))
enc_emb = Embedding(eng_vocab_size, latent_dim)(encoder_inputs)

encoder_lstm = LSTM(latent_dim, return_state=True)
_, state_h, state_c = encoder_lstm(enc_emb)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(max_fr_len,))
dec_emb_layer = Embedding(fr_vocab_size, latent_dim)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=encoder_states)

decoder_dense = Dense(fr_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Seq2Seq model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 4)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_1             │ (None, 3)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding (Embedding)     │ (None, 4, 256)         │          3,840 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_1 (Embedding)   │ (None, 3, 256)         │          3,584 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm (LSTM)               │ [(None, 256), (None,   │        525,312 │ embedding[0][0]        │
# │                           │ 256), (None, 256)]     │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_1 (LSTM)             │ [(None, 3, 256),       │        525,312 │ embedding_1[0][0],     │
# │                           │ (None, 256), (None,    │                │ lstm[0][1], lstm[0][2] │
# │                           │ 256)]                  │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 3, 14)          │          3,598 │ lstm_1[0][0]           │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,061,646 (4.05 MB)
#  Trainable params: 1,061,646 (4.05 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# (c) Preparing the Data for Training

# %%
# Preparing decoder target data (shifted French sentences)
fr_padded_target = np.zeros_like(fr_padded)
fr_padded_target[:, :-1] = fr_padded[:, 1:]

# Train/Val Split
train_size = int(0.8 * len(eng_padded))
eng_train, eng_val = eng_padded[:train_size], eng_padded[train_size:]
fr_train, fr_val = fr_padded[:train_size], fr_padded[train_size:]
fr_target_train, fr_target_val = fr_padded_target[:train_size], fr_padded_target[train_size:]

# %% [markdown]
# (d) Train the Model on the Dataset

# %%
batch_size = 64
epochs = 100

history = model.fit([eng_train, fr_train], fr_target_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=([eng_val, fr_val], fr_target_val))
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.2000 - loss: 2.6323 - val_accuracy: 0.8333 - val_loss: 2.5742
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5333 - loss: 2.5864 - val_accuracy: 0.8333 - val_loss: 2.5078
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5333 - loss: 2.5374 - val_accuracy: 0.8333 - val_loss: 2.4293
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5333 - loss: 2.4807 - val_accuracy: 0.8333 - val_loss: 2.3307
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5333 - loss: 2.4112 - val_accuracy: 0.8333 - val_loss: 2.2026
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5333 - loss: 2.3230 - val_accuracy: 0.8333 - val_loss: 2.0345
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5333 - loss: 2.2091 - val_accuracy: 0.8333 - val_loss: 1.8158
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5333 - loss: 2.0631 - val_accuracy: 0.8333 - val_loss: 1.5425
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 1.8829 - val_accuracy: 0.8333 - val_loss: 1.2381
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 1.6829 - val_accuracy: 0.8333 - val_loss: 0.9845
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5333 - loss: 1.5056 - val_accuracy: 0.8333 - val_loss: 0.8805
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.5333 - loss: 1.4155 - val_accuracy: 0.8333 - val_loss: 0.9263
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5333 - loss: 1.4403 - val_accuracy: 0.8333 - val_loss: 1.0124
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.5333 - loss: 1.4845 - val_accuracy: 0.8333 - val_loss: 1.0615
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5333 - loss: 1.4607 - val_accuracy: 0.8333 - val_loss: 1.0700
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5333 - loss: 1.3805 - val_accuracy: 0.8333 - val_loss: 1.0553
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 1.2845 - val_accuracy: 0.8333 - val_loss: 1.0357
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.5333 - loss: 1.2039 - val_accuracy: 0.8333 - val_loss: 1.0239
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5333 - loss: 1.1505 - val_accuracy: 0.8333 - val_loss: 1.0249
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5333 - loss: 1.1199 - val_accuracy: 0.8333 - val_loss: 1.0374
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5333 - loss: 1.1004 - val_accuracy: 0.8333 - val_loss: 1.0567
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.6000 - loss: 1.0805 - val_accuracy: 0.8333 - val_loss: 1.0783
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6000 - loss: 1.0525 - val_accuracy: 0.8333 - val_loss: 1.0999
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6000 - loss: 1.0131 - val_accuracy: 0.8333 - val_loss: 1.1222
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6000 - loss: 0.9627 - val_accuracy: 0.8333 - val_loss: 1.1480
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6000 - loss: 0.9042 - val_accuracy: 0.8333 - val_loss: 1.1808
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.6000 - loss: 0.8422 - val_accuracy: 0.8333 - val_loss: 1.2237
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6000 - loss: 0.7811 - val_accuracy: 0.8333 - val_loss: 1.2777
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6000 - loss: 0.7234 - val_accuracy: 0.8333 - val_loss: 1.3412
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7333 - loss: 0.6687 - val_accuracy: 0.8333 - val_loss: 1.4107
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.7333 - loss: 0.6149 - val_accuracy: 0.8333 - val_loss: 1.4817
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.7333 - loss: 0.5598 - val_accuracy: 0.8333 - val_loss: 1.5505
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8667 - loss: 0.5040 - val_accuracy: 0.8333 - val_loss: 1.6155
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9333 - loss: 0.4506 - val_accuracy: 0.8333 - val_loss: 1.6769
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9333 - loss: 0.4034 - val_accuracy: 0.8333 - val_loss: 1.7372
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9333 - loss: 0.3616 - val_accuracy: 0.8333 - val_loss: 1.7992
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.3189 - val_accuracy: 0.8333 - val_loss: 1.8647
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.2775 - val_accuracy: 0.8333 - val_loss: 1.9345
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.2456 - val_accuracy: 0.8333 - val_loss: 2.0093
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.2204 - val_accuracy: 0.8333 - val_loss: 2.0898
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.1948 - val_accuracy: 0.8333 - val_loss: 2.1755
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.1673 - val_accuracy: 0.8333 - val_loss: 2.2642
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 0.1421 - val_accuracy: 0.8333 - val_loss: 2.3530
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.1228 - val_accuracy: 0.8333 - val_loss: 2.4390
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.1093 - val_accuracy: 0.8333 - val_loss: 2.5202
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 0.0981 - val_accuracy: 0.8333 - val_loss: 2.5951
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0859 - val_accuracy: 0.8333 - val_loss: 2.6623
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 0.0737 - val_accuracy: 0.8333 - val_loss: 2.7213
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 1.0000 - loss: 0.0636 - val_accuracy: 0.8333 - val_loss: 2.7728
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 1.0000 - loss: 0.0555 - val_accuracy: 0.8333 - val_loss: 2.8183
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 1.0000 - loss: 0.0489 - val_accuracy: 0.8333 - val_loss: 2.8598
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 1.0000 - loss: 0.0430 - val_accuracy: 0.8333 - val_loss: 2.8994
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 1.0000 - loss: 0.0376 - val_accuracy: 0.8333 - val_loss: 2.9388
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 1.0000 - loss: 0.0327 - val_accuracy: 0.8333 - val_loss: 2.9789
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0288 - val_accuracy: 0.8333 - val_loss: 3.0198
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 1.0000 - loss: 0.0258 - val_accuracy: 0.8333 - val_loss: 3.0611
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 1.0000 - loss: 0.0232 - val_accuracy: 0.8333 - val_loss: 3.1017
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 1.0000 - loss: 0.0206 - val_accuracy: 0.8333 - val_loss: 3.1403
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 0.0182 - val_accuracy: 0.8333 - val_loss: 3.1754
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 0.8333 - val_loss: 3.2064
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.8333 - val_loss: 3.2327
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.8333 - val_loss: 3.2544
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 0.8333 - val_loss: 3.2717
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 0.8333 - val_loss: 3.2850
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.8333 - val_loss: 3.2952
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.8333 - val_loss: 3.3030
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.8333 - val_loss: 3.3093
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.8333 - val_loss: 3.3147
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.8333 - val_loss: 3.3202
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.8333 - val_loss: 3.3261
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.8333 - val_loss: 3.3328
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.8333 - val_loss: 3.3406
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8333 - val_loss: 3.3493
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.8333 - val_loss: 3.3587
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.8333 - val_loss: 3.3685
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.8333 - val_loss: 3.3782
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.8333 - val_loss: 3.3875
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.8333 - val_loss: 3.3962
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.8333 - val_loss: 3.4039
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8333 - val_loss: 3.4105
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.8333 - val_loss: 3.4160
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8333 - val_loss: 3.4204
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8333 - val_loss: 3.4238
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.8333 - val_loss: 3.4263
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8333 - val_loss: 3.4281
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.8333 - val_loss: 3.4294
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8333 - val_loss: 3.4303
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8333 - val_loss: 3.4312
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8333 - val_loss: 3.4320
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8333 - val_loss: 3.4330
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8333 - val_loss: 3.4341
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8333 - val_loss: 3.4356
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8333 - val_loss: 3.4373
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.8333 - val_loss: 3.4393
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.8333 - val_loss: 3.4416
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8333 - val_loss: 3.4440
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8333 - val_loss: 3.4465
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8333 - val_loss: 3.4490
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8333 - val_loss: 3.4514
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8333 - val_loss: 3.4537

# %% [markdown]
# (e) Inference Setup for Translation

# %%
# Inference Encoder
encoder_model = Model(encoder_inputs, encoder_states)

# Inference Decoder
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

dec_emb2 = dec_emb_layer(decoder_inputs)

decoder_outputs2, state_h2, state_c2 = decoder_lstm(
    dec_emb2, initial_state=decoder_states_inputs)
decoder_states2 = [state_h2, state_c2]
decoder_outputs2 = decoder_dense(decoder_outputs2)

decoder_model = Model([decoder_inputs] + decoder_states_inputs,
                      [decoder_outputs2] + decoder_states2)

# %% [markdown]
# (f) Translate New Sentences

# %%
# Add 'start' and 'end' tokens to French sentences
french_sentences_with_tokens = ['start ' + sent + ' end' for sent in french_sentences]

# Tokenize French sentences with start and end tokens
fr_tokenizer = Tokenizer()
fr_tokenizer.fit_on_texts(french_sentences_with_tokens)
fr_sequences = fr_tokenizer.texts_to_sequences(french_sentences_with_tokens)
fr_word_index = fr_tokenizer.word_index
max_fr_len = max(len(seq) for seq in fr_sequences)

# Padding sequences
eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
fr_padded = pad_sequences(fr_sequences, maxlen=max_fr_len, padding='post')

# %%
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)

    # Start with the 'start' token
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = fr_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = None
        for word, index in fr_word_index.items():
            if index == sampled_token_index:
                sampled_word = word
                break

        if sampled_word == 'end' or len(decoded_sentence) > max_fr_len:
            stop_condition = True
        else:
            decoded_sentence += sampled_word + ' '

        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index
        states_value = [h, c]

    return decoded_sentence

# %%
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)

    # Start with the 'start' token
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = fr_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Get the index of the most likely next word
        sampled_token_index = np.argmax(output_tokens[0, -1, :])

        # Retrieve the corresponding word for the token index
        sampled_word = None
        for word, index in fr_word_index.items():
            if index == sampled_token_index:
                sampled_word = word
                break

        # Handle the case where the word is not found
        if sampled_word is None:
            print(f"Warning: No word found for token index {sampled_token_index}")
            stop_condition = True
        elif sampled_word == 'end' or len(decoded_sentence.split()) > max_fr_len:
            stop_condition = True
        else:
            decoded_sentence += sampled_word + ' '

        # Update the target sequence to the predicted word
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states for the next iteration
        states_value = [h, c]

    return decoded_sentence

# %%
# Testing with a new sentence
test_sentence = "hello"
test_sequence = eng_tokenizer.texts_to_sequences([test_sentence])
test_sequence = pad_sequences(test_sequence, maxlen=max_eng_len, padding='post')

translation = decode_sequence(test_sequence)
print(f"Translation: {translation}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Warning: No word found for token index 0
# Translation:

# %% [markdown]
# (g) Experimenting and Improving the Model with a Larger Dataset

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.optimizers import Adam

# Define the latent_dim and other hyperparameters
latent_dim = 256
eng_vocab_size = 15  # Example value; replace with actual vocab size
fr_vocab_size = 15   # Example value; replace with actual vocab size
embedding_dim = 128  # Size of the embedding vectors

# Define encoder
encoder_inputs = Input(shape=(None,))  # Only the sequence length is needed here
encoder_embedding = Embedding(input_dim=eng_vocab_size, output_dim=embedding_dim)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_sequences=True)(encoder_embedding)
encoder_outputs, state_h, state_c = LSTM(latent_dim, return_state=True)(encoder_lstm)
encoder_states = [state_h, state_c]

# Define decoder
decoder_inputs = Input(shape=(None,))  # Only the sequence length is needed here
decoder_embedding = Embedding(input_dim=fr_vocab_size, output_dim=embedding_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True)(decoder_embedding, initial_state=encoder_states)
decoder_outputs = Dense(fr_vocab_size, activation='softmax')(decoder_lstm)

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
opt = Adam(learning_rate=0.0005)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Check the shapes of the training data
# Ensure eng_train, fr_train, and fr_target_train have the appropriate shapes
print(f"eng_train shape: {eng_train.shape}, fr_train shape: {fr_train.shape}, fr_target_train shape: {fr_target_train.shape}")

# Train the model
model.fit([eng_train, fr_train], fr_target_train, batch_size=batch_size, epochs=200, validation_data=([eng_val, fr_val], fr_target_val))
# Out:
# eng_train shape: (5, 4), fr_train shape: (5, 3), fr_target_train shape: (5, 3)
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - accuracy: 0.0000e+00 - loss: 2.7077 - val_accuracy: 0.8333 - val_loss: 2.6918
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 668ms/step - accuracy: 0.4667 - loss: 2.6961 - val_accuracy: 0.8333 - val_loss: 2.6778
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.5333 - loss: 2.6842 - val_accuracy: 0.8333 - val_loss: 2.6626
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5333 - loss: 2.6716 - val_accuracy: 0.8333 - val_loss: 2.6456
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5333 - loss: 2.6578 - val_accuracy: 0.8333 - val_loss: 2.6261
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5333 - loss: 2.6423 - val_accuracy: 0.8333 - val_loss: 2.6031
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 2.6245 - val_accuracy: 0.8333 - val_loss: 2.5757
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.5333 - loss: 2.6037 - val_accuracy: 0.8333 - val_loss: 2.5425
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.5333 - loss: 2.5789 - val_accuracy: 0.8333 - val_loss: 2.5020
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5333 - loss: 2.5492 - val_accuracy: 0.8333 - val_loss: 2.4523
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5333 - loss: 2.5131 - val_accuracy: 0.8333 - val_loss: 2.3910
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5333 - loss: 2.4690 - val_accuracy: 0.8333 - val_loss: 2.3152
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 2.4147 - val_accuracy: 0.8333 - val_loss: 2.2214
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5333 - loss: 2.3476 - val_accuracy: 0.8333 - val_loss: 2.1051
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5333 - loss: 2.2647 - val_accuracy: 0.8333 - val_loss: 1.9619
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5333 - loss: 2.1629 - val_accuracy: 0.8333 - val_loss: 1.7878
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5333 - loss: 2.0402 - val_accuracy: 0.8333 - val_loss: 1.5822
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.5333 - loss: 1.8982 - val_accuracy: 0.8333 - val_loss: 1.3553
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5333 - loss: 1.7475 - val_accuracy: 0.8333 - val_loss: 1.1370
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5333 - loss: 1.6123 - val_accuracy: 0.8333 - val_loss: 0.9755
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5333 - loss: 1.5333 - val_accuracy: 0.8333 - val_loss: 0.9071
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 1.5457 - val_accuracy: 0.8333 - val_loss: 0.9141
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.5333 - loss: 1.6073 - val_accuracy: 0.8333 - val_loss: 0.9384
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5333 - loss: 1.6349 - val_accuracy: 0.8333 - val_loss: 0.9514
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.5333 - loss: 1.6077 - val_accuracy: 0.8333 - val_loss: 0.9518
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5333 - loss: 1.5459 - val_accuracy: 0.8333 - val_loss: 0.9470
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.5333 - loss: 1.4763 - val_accuracy: 0.8333 - val_loss: 0.9448
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.5333 - loss: 1.4186 - val_accuracy: 0.8333 - val_loss: 0.9498
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.5333 - loss: 1.3817 - val_accuracy: 0.8333 - val_loss: 0.9624
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5333 - loss: 1.3645 - val_accuracy: 0.8333 - val_loss: 0.9794
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5333 - loss: 1.3597 - val_accuracy: 0.8333 - val_loss: 0.9965
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.5333 - loss: 1.3593 - val_accuracy: 0.8333 - val_loss: 1.0104
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.5333 - loss: 1.3570 - val_accuracy: 0.8333 - val_loss: 1.0193
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.5333 - loss: 1.3493 - val_accuracy: 0.8333 - val_loss: 1.0235
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.5333 - loss: 1.3350 - val_accuracy: 0.8333 - val_loss: 1.0248
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.5333 - loss: 1.3148 - val_accuracy: 0.8333 - val_loss: 1.0258
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.5333 - loss: 1.2903 - val_accuracy: 0.8333 - val_loss: 1.0295
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.5333 - loss: 1.2639 - val_accuracy: 0.8333 - val_loss: 1.0384
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.5333 - loss: 1.2382 - val_accuracy: 0.8333 - val_loss: 1.0541
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.5333 - loss: 1.2156 - val_accuracy: 0.8333 - val_loss: 1.0767
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.5333 - loss: 1.1976 - val_accuracy: 0.8333 - val_loss: 1.1052
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.5333 - loss: 1.1840 - val_accuracy: 0.8333 - val_loss: 1.1370
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.5333 - loss: 1.1734 - val_accuracy: 0.8333 - val_loss: 1.1694
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5333 - loss: 1.1633 - val_accuracy: 0.8333 - val_loss: 1.1996
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.5333 - loss: 1.1514 - val_accuracy: 0.8333 - val_loss: 1.2258
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.5333 - loss: 1.1363 - val_accuracy: 0.8333 - val_loss: 1.2476
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5333 - loss: 1.1182 - val_accuracy: 0.8333 - val_loss: 1.2656
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5333 - loss: 1.0981 - val_accuracy: 0.8333 - val_loss: 1.2812
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5333 - loss: 1.0777 - val_accuracy: 0.8333 - val_loss: 1.2962
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.5333 - loss: 1.0583 - val_accuracy: 0.8333 - val_loss: 1.3122
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.5333 - loss: 1.0407 - val_accuracy: 0.8333 - val_loss: 1.3306
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5333 - loss: 1.0246 - val_accuracy: 0.8333 - val_loss: 1.3522
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5333 - loss: 1.0091 - val_accuracy: 0.8333 - val_loss: 1.3775
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5333 - loss: 0.9930 - val_accuracy: 0.8333 - val_loss: 1.4068
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5333 - loss: 0.9754 - val_accuracy: 0.8333 - val_loss: 1.4404
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 0.9556 - val_accuracy: 0.8333 - val_loss: 1.4784
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5333 - loss: 0.9338 - val_accuracy: 0.8333 - val_loss: 1.5207
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.5333 - loss: 0.9107 - val_accuracy: 0.8333 - val_loss: 1.5672
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.5333 - loss: 0.8871 - val_accuracy: 0.8333 - val_loss: 1.6167
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.5333 - loss: 0.8636 - val_accuracy: 0.8333 - val_loss: 1.6681
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.5333 - loss: 0.8404 - val_accuracy: 0.8333 - val_loss: 1.7195
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5333 - loss: 0.8169 - val_accuracy: 0.8333 - val_loss: 1.7693
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5333 - loss: 0.7922 - val_accuracy: 0.8333 - val_loss: 1.8165
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5333 - loss: 0.7657 - val_accuracy: 0.8333 - val_loss: 1.8607
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.5333 - loss: 0.7373 - val_accuracy: 0.8333 - val_loss: 1.9027
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.7333 - loss: 0.7075 - val_accuracy: 0.8333 - val_loss: 1.9438
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7333 - loss: 0.6768 - val_accuracy: 0.8333 - val_loss: 1.9854
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8000 - loss: 0.6460 - val_accuracy: 0.8333 - val_loss: 2.0290
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8000 - loss: 0.6150 - val_accuracy: 0.8333 - val_loss: 2.0755
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8667 - loss: 0.5834 - val_accuracy: 0.8333 - val_loss: 2.1252
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.8667 - loss: 0.5508 - val_accuracy: 0.8333 - val_loss: 2.1781
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8667 - loss: 0.5171 - val_accuracy: 0.8333 - val_loss: 2.2335
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8667 - loss: 0.4830 - val_accuracy: 0.8333 - val_loss: 2.2900
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8667 - loss: 0.4493 - val_accuracy: 0.8333 - val_loss: 2.3459
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8667 - loss: 0.4168 - val_accuracy: 0.8333 - val_loss: 2.3991
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9333 - loss: 0.3855 - val_accuracy: 0.8333 - val_loss: 2.4480
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9333 - loss: 0.3553 - val_accuracy: 0.8333 - val_loss: 2.4918
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 1.0000 - loss: 0.3263 - val_accuracy: 0.8333 - val_loss: 2.5310
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.2988 - val_accuracy: 0.6667 - val_loss: 2.5668
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 1.0000 - loss: 0.2734 - val_accuracy: 0.6667 - val_loss: 2.6011
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 1.0000 - loss: 0.2502 - val_accuracy: 0.6667 - val_loss: 2.6356
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 1.0000 - loss: 0.2290 - val_accuracy: 0.8333 - val_loss: 2.6713
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 1.0000 - loss: 0.2094 - val_accuracy: 0.8333 - val_loss: 2.7081
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 0.1912 - val_accuracy: 0.8333 - val_loss: 2.7448
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 1.0000 - loss: 0.1745 - val_accuracy: 0.8333 - val_loss: 2.7795
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 1.0000 - loss: 0.1591 - val_accuracy: 0.8333 - val_loss: 2.8104
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.1446 - val_accuracy: 0.8333 - val_loss: 2.8366
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.1308 - val_accuracy: 0.8333 - val_loss: 2.8580
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 0.1180 - val_accuracy: 0.8333 - val_loss: 2.8758
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 1.0000 - loss: 0.1065 - val_accuracy: 0.8333 - val_loss: 2.8912
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0967 - val_accuracy: 0.8333 - val_loss: 2.9060
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 0.0884 - val_accuracy: 0.8333 - val_loss: 2.9209
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 1.0000 - loss: 0.0811 - val_accuracy: 0.8333 - val_loss: 2.9361
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0746 - val_accuracy: 0.8333 - val_loss: 2.9512
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 0.0687 - val_accuracy: 0.8333 - val_loss: 2.9652
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 1.0000 - loss: 0.0633 - val_accuracy: 0.8333 - val_loss: 2.9777
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 1.0000 - loss: 0.0581 - val_accuracy: 0.8333 - val_loss: 2.9885
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - loss: 0.0533 - val_accuracy: 0.8333 - val_loss: 2.9979
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0488 - val_accuracy: 0.8333 - val_loss: 3.0067
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0449 - val_accuracy: 0.8333 - val_loss: 3.0153
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0416 - val_accuracy: 0.8333 - val_loss: 3.0241
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0387 - val_accuracy: 0.8333 - val_loss: 3.0331
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 1.0000 - loss: 0.0362 - val_accuracy: 0.8333 - val_loss: 3.0418
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.0340 - val_accuracy: 0.8333 - val_loss: 3.0497
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 1.0000 - loss: 0.0320 - val_accuracy: 0.8333 - val_loss: 3.0563
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0301 - val_accuracy: 0.8333 - val_loss: 3.0615
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 1.0000 - loss: 0.0285 - val_accuracy: 0.8333 - val_loss: 3.0657
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 1.0000 - loss: 0.0269 - val_accuracy: 0.8333 - val_loss: 3.0692
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 1.0000 - loss: 0.0254 - val_accuracy: 0.8333 - val_loss: 3.0725
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 1.0000 - loss: 0.0240 - val_accuracy: 0.8333 - val_loss: 3.0758
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 1.0000 - loss: 0.0227 - val_accuracy: 0.8333 - val_loss: 3.0793
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 1.0000 - loss: 0.0215 - val_accuracy: 0.8333 - val_loss: 3.0828
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 1.0000 - loss: 0.0205 - val_accuracy: 0.8333 - val_loss: 3.0862
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 0.8333 - val_loss: 3.0892
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 1.0000 - loss: 0.0186 - val_accuracy: 0.8333 - val_loss: 3.0920
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 1.0000 - loss: 0.0178 - val_accuracy: 0.8333 - val_loss: 3.0945
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 1.0000 - loss: 0.0171 - val_accuracy: 0.8333 - val_loss: 3.0971
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 0.8333 - val_loss: 3.0999
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.8333 - val_loss: 3.1031
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.8333 - val_loss: 3.1065
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.8333 - val_loss: 3.1102
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.8333 - val_loss: 3.1138
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.8333 - val_loss: 3.1172
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 0.8333 - val_loss: 3.1204
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.8333 - val_loss: 3.1234
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 0.8333 - val_loss: 3.1263
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.8333 - val_loss: 3.1291
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.8333 - val_loss: 3.1320
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.8333 - val_loss: 3.1348
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.8333 - val_loss: 3.1377
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.8333 - val_loss: 3.1405
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.8333 - val_loss: 3.1431
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.8333 - val_loss: 3.1454
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.8333 - val_loss: 3.1475
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.8333 - val_loss: 3.1493
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.8333 - val_loss: 3.1509
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.8333 - val_loss: 3.1524
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.8333 - val_loss: 3.1538
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.8333 - val_loss: 3.1553
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.8333 - val_loss: 3.1567
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.8333 - val_loss: 3.1582
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.8333 - val_loss: 3.1596
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.8333 - val_loss: 3.1610
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.8333 - val_loss: 3.1623
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.8333 - val_loss: 3.1635
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.8333 - val_loss: 3.1646
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.8333 - val_loss: 3.1657
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.8333 - val_loss: 3.1668
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.8333 - val_loss: 3.1679
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.8333 - val_loss: 3.1690
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8333 - val_loss: 3.1702
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.8333 - val_loss: 3.1715
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.8333 - val_loss: 3.1728
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.8333 - val_loss: 3.1741
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.8333 - val_loss: 3.1754
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.8333 - val_loss: 3.1766
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.8333 - val_loss: 3.1778
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.8333 - val_loss: 3.1790
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.8333 - val_loss: 3.1801
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.8333 - val_loss: 3.1812
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.8333 - val_loss: 3.1823
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.8333 - val_loss: 3.1834
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.8333 - val_loss: 3.1846
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.8333 - val_loss: 3.1858
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.8333 - val_loss: 3.1870
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.8333 - val_loss: 3.1882
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.8333 - val_loss: 3.1894
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.8333 - val_loss: 3.1906
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.8333 - val_loss: 3.1917
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.8333 - val_loss: 3.1928
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8333 - val_loss: 3.1939
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8333 - val_loss: 3.1949
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.8333 - val_loss: 3.1959
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.8333 - val_loss: 3.1968
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.8333 - val_loss: 3.1978
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8333 - val_loss: 3.1987
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8333 - val_loss: 3.1997
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8333 - val_loss: 3.2006
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.8333 - val_loss: 3.2016
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.8333 - val_loss: 3.2025
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.8333 - val_loss: 3.2034
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.8333 - val_loss: 3.2044
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8333 - val_loss: 3.2053
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8333 - val_loss: 3.2062
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.8333 - val_loss: 3.2070
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.8333 - val_loss: 3.2078
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8333 - val_loss: 3.2086
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8333 - val_loss: 3.2094
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8333 - val_loss: 3.2102
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8333 - val_loss: 3.2110
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8333 - val_loss: 3.2117
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8333 - val_loss: 3.2125
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8333 - val_loss: 3.2132
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8333 - val_loss: 3.2140
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8333 - val_loss: 3.2147
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8333 - val_loss: 3.2155
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8333 - val_loss: 3.2162
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8333 - val_loss: 3.2169
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8333 - val_loss: 3.2176
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8333 - val_loss: 3.2183
